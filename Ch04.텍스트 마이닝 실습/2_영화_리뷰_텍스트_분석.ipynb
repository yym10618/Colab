# %% [markdown]
# <a href="https://colab.research.google.com/github/yym10618/Colab/blob/master/Ch04.%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%A7%88%EC%9D%B4%EB%8B%9D%20%EC%8B%A4%EC%8A%B5/2_%EC%98%81%ED%99%94_%EB%A6%AC%EB%B7%B0_%ED%85%8D%EC%8A%A4%ED%8A%B8_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#konlpy 패키지 설치
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 43.6 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.2.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.3.0 konlpy-0.6.0

# %%
"""
날짜 : 2022/05/17
이름 : 양용민
내용 : 영화 리뷰 텍스트 분석 실습
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle, re
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, Embedding, LSTM
from konlpy.tag import Okt

# %%
# 텍스트 데이터 불러오기
train_data = pd.read_table('/content/drive/MyDrive/파이썬 데이터 과학 실습/file/movie_review_train.txt')
test_data = pd.read_table('/content/drive/MyDrive/파이썬 데이터 과학 실습/file/movie_review_test.txt')
train_data
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                                한국 영화 최초의 아카데미 수상작!      1
#
# [150000 rows x 3 columns]

# %%
##################################################################
# 텍스트 전처리
##################################################################

# 분석기 생성
okt = Okt()

# 불용어 정의
stop_words = ['은', '는', '이', '가', '하', '것', '들', '의', '있', '되', '등', '한']

# 전처리 함수 정의
def preprocessing(txt):
  # 한글 텍스트가 아닌 문장 제거
  text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", str(txt))

  # 문장 형태소 분석
  text = okt.morphs(text, stem=True)
  
  # 불용어 제거
  word_text = [w for w in text if not w in stop_words]

  return word_text

result1 = preprocessing('아 더빙.. 진짜 짜증나네요 목소리');
result2 = preprocessing('흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나');
print('result1 :', result1)
print('result2 :', result2)
# Out:
# result1 : ['아', '더빙', '진짜', '짜증나다', '목소리']
# result2 : ['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '조차', '가볍다', '않다']

# %%
# 훈련, 검증 데이터 전처리
train_txt = []
test_txt = []
for txt in train_data['document']:
  train_txt.append(preprocessing(txt))
for txt in test_data['document']:
  test_txt.append(preprocessing(txt))

train_txt[:4]
# Out:
# [['아', '더빙', '진짜', '짜증나다', '목소리'],
#  ['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '조차', '가볍다', '않다'],
#  ['너', '무재', '밓었', '다그', '래서', '보다', '추천', '다'],
#  ['교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정']]

# %%
# 토큰화
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_txt)

train_sequences = tokenizer.texts_to_sequences(train_txt)
test_sequences = tokenizer.texts_to_sequences(test_txt)

word_index = tokenizer.word_index
word_index

# 토큰 저장
with open('/content/drive/MyDrive/파이썬 데이터 과학 실습/file/movie_tokenizer.pickle', 'wb') as handle:
  pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# {'영화': 1,
#  '보다': 2,
#  '하다': 3,
#  '에': 4,
#  '을': 5,
#  '도': 6,
#  '를': 7,
#  '없다': 8,
#  '이다': 9,
#  '있다': 10,
#  '좋다': 11,
#  '너무': 12,
#  '다': 13,
#  '정말': 14,
#  '재밌다': 15,
#  '되다': 16,
#  '적': 17,
#  '만': 18,
#  '같다': 19,
#  '진짜': 20,
#  '으로': 21,
#  '로': 22,
#  '아니다': 23,
#  '않다': 24,
#  '점': 25,
#  '에서': 26,
#  '만들다': 27,
#  '과': 28,
#  '나오다': 29,
#  '연기': 30,
#  '평점': 31,
#  '최고': 32,
#  '내': 33,
#  '그': 34,
#  '나': 35,
#  '안': 36,
#  '인': 37,
#  '스토리': 38,
#  '생각': 39,
#  '못': 40,
#  '왜': 41,
#  '드라마': 42,
#  '게': 43,
#  '감동': 44,
#  '사람': 45,
#  '보고': 46,
#  '이렇다': 47,
#  '말': 48,
#  '아깝다': 49,
#  '고': 50,
#  '더': 51,
#  'ㅋㅋ': 52,
#  '배우': 53,
#  '때': 54,
#  '와': 55,
#  '아': 56,
#  '재미있다': 57,
#  '감독': 58,
#  '거': 59,
#  '그냥': 60,
#  '요': 61,
#  '재미': 62,
#  '시간': 63,
#  '내용': 64,
#  '뭐': 65,
#  '까지': 66,
#  '중': 67,
#  '주다': 68,
#  '재미없다': 69,
#  '자다': 70,
#  '좀': 71,
#  '쓰레기': 72,
#  '하고': 73,
#  '지루하다': 74,
#  '네': 75,
#  '수': 76,
#  '모르다': 77,
#  '가다': 78,
#  '들다': 79,
#  '그렇다': 80,
#  '싶다': 81,
#  '지': 82,
#  '작품': 83,
#  '사랑': 84,
#  '알다': 85,
#  '하나': 86,
#  '다시': 87,
#  '볼': 88,
#  '마지막': 89,
#  '잘': 90,
#  '이건': 91,
#  '정도': 92,
#  '저': 93,
#  '완전': 94,
#  'ㅋ': 95,
#  '오다': 96,
#  'ㅠㅠ': 97,
#  '많다': 98,
#  'ㅋㅋㅋ': 99,
#  '처음': 100,
#  '장면': 101,
#  '액션': 102,
#  '주인공': 103,
#  '이렇게': 104,
#  '걸': 105,
#  '안되다': 106,
#  '차다': 107,
#  '최악': 108,
#  '나다': 109,
#  '개': 110,
#  '돈': 111,
#  '이야기': 112,
#  '지금': 113,
#  '별로': 114,
#  '넘다': 115,
#  '느낌': 116,
#  '임': 117,
#  'ㅡㅡ': 118,
#  '연출': 119,
#  '라': 120,
#  '인데': 121,
#  '명작': 122,
#  '듯': 123,
#  '끝': 124,
#  '좋아하다': 125,
#  '그리고': 126,
#  '역시': 127,
#  '기': 128,
#  '년': 129,
#  '받다': 130,
#  '별': 131,
#  '많이': 132,
#  '남다': 133,
#  '이해': 134,
#  '난': 135,
#  '면': 136,
#  '이런': 137,
#  '괜찮다': 138,
#  '이영화': 139,
#  '분': 140,
#  '라고': 141,
#  '느끼다': 142,
#  '또': 143,
#  '버리다': 144,
#  '이나': 145,
#  '때문': 146,
#  '성': 147,
#  '여자': 148,
#  '서': 149,
#  '부터': 150,
#  '먹다': 151,
#  '일': 152,
#  '아름답다': 153,
#  '해주다': 154,
#  '꼭': 155,
#  '보기': 156,
#  '엔': 157,
#  '에게': 158,
#  '두': 159,
#  '이고': 160,
#  '무슨': 161,
#  '여': 162,
#  '짱': 163,
#  '기억': 164,
#  '결말': 165,
#  'ㅎㅎ': 166,
#  '편': 167,
#  '대': 168,
#  '마음': 169,
#  '랑': 170,
#  '야': 171,
#  '전': 172,
#  '인생': 173,
#  '아쉽다': 174,
#  '영': 175,
#  '소재': 176,
#  '뻔하다': 177,
#  '끄다': 178,
#  '어떻다': 179,
#  '애': 180,
#  '보여주다': 181,
#  '님': 182,
#  '없이': 183,
#  '수준': 184,
#  '어리다': 185,
#  '현실': 186,
#  '무섭다': 187,
#  '재다': 188,
#  '맞다': 189,
#  '속': 190,
#  '한번': 191,
#  '씨': 192,
#  '가장': 193,
#  '본': 194,
#  '급': 195,
#  '웃기다': 196,
#  '매력': 197,
#  '반전': 198,
#  '되어다': 199,
#  '전개': 200,
#  '제': 201,
#  '라는': 202,
#  '한국': 203,
#  '남자': 204,
#  '끝나다': 205,
#  '가슴': 206,
#  '뿐': 207,
#  '말다': 208,
#  '낮다': 209,
#  '아이': 210,
#  '슬프다': 211,
#  '죽다': 212,
#  '높다': 213,
#  '유치하다': 214,
#  '알': 215,
#  '멋지다': 216,
#  '음악': 217,
#  '니': 218,
#  '다른': 219,
#  '원작': 220,
#  '줄': 221,
#  '늘다': 222,
#  '화': 223,
#  '인간': 224,
#  '냐': 225,
#  '솔직하다': 226,
#  '크다': 227,
#  '추천': 228,
#  '우리': 229,
#  '쓰다': 230,
#  '눈물': 231,
#  '인지': 232,
#  '살다': 233,
#  '함': 234,
#  '모든': 235,
#  '지만': 236,
#  '내다': 237,
#  '자체': 238,
#  '번': 239,
#  '야하다': 240,
#  '허다': 241,
#  '눈': 242,
#  '찍다': 243,
#  '하지만': 244,
#  '인가': 245,
#  '보이다': 246,
#  '캐릭터': 247,
#  '대박': 248,
#  '코미디': 249,
#  '처럼': 250,
#  'ㅋㅋㅋㅋ': 251,
#  '움': 252,
#  '대한': 253,
#  '모두': 254,
#  '뭔가': 255,
#  '이상': 256,
#  '돼다': 257,
#  'ㅠ': 258,
#  '이네': 259,
#  '전혀': 260,
#  '이쁘다': 261,
#  '연기력': 262,
#  '건지다': 263,
#  '여운': 264,
#  '미치다': 265,
#  '그래도': 266,
#  '짜증나다': 267,
#  '개봉': 268,
#  '공감': 269,
#  '기대하다': 270,
#  '기대': 271,
#  '일본': 272,
#  '시리즈': 273,
#  '지다': 274,
#  '근데': 275,
#  '중간': 276,
#  '표현': 277,
#  '굿': 278,
#  '아주': 279,
#  '영상': 280,
#  '부분': 281,
#  '모습': 282,
#  '에는': 283,
#  '작': 284,
#  '계속': 285,
#  '제목': 286,
#  '이랑': 287,
#  '귀엽다': 288,
#  'ㅜㅜ': 289,
#  '치다': 290,
#  '시키다': 291,
#  '이라': 292,
#  '자': 293,
#  '가족': 294,
#  '내내': 295,
#  '보지': 296,
#  '뭔': 297,
#  '믿다': 298,
#  '진심': 299,
#  '실망': 300,
#  '몰입': 301,
#  '밖에': 302,
#  '후': 303,
#  'ㅎ': 304,
#  '짜다': 305,
#  '대단하다': 306,
#  '기분': 307,
#  '연': 308,
#  '떨어지다': 309,
#  '작가': 310,
#  '건': 311,
#  '잔잔하다': 312,
#  '이제': 313,
#  '위': 314,
#  '웃다': 315,
#  '요즘': 316,
#  '잼': 317,
#  '빠지다': 318,
#  '공포': 319,
#  '스릴러': 320,
#  '이라는': 321,
#  '시': 322,
#  '용': 323,
#  '감': 324,
#  '긴장감': 325,
#  '개인': 326,
#  '점도': 327,
#  '조금': 328,
#  '알바': 329,
#  '애니': 330,
#  '대사': 331,
#  '이유': 332,
#  '특히': 333,
#  '제대로': 334,
#  '삶': 335,
#  '울다': 336,
#  '극장': 337,
#  '노래': 338,
#  '노잼': 339,
#  '한테': 340,
#  '딱': 341,
#  '점수': 342,
#  '욕': 343,
#  '잇다': 344,
#  '시작': 345,
#  '막장': 346,
#  '이란': 347,
#  '나름': 348,
#  '이상하다': 349,
#  '오랜': 350,
#  '극': 351,
#  '이지': 352,
#  '예쁘다': 353,
#  '깊다': 354,
#  '에도': 355,
#  '제일': 356,
#  '차라리': 357,
#  '놈': 358,
#  '느껴지다': 359,
#  '친구': 360,
#  '영화로': 361,
#  '해보다': 362,
#  '당시': 363,
#  '같이': 364,
#  '어설프다': 365,
#  '의미': 366,
#  '절대': 367,
#  '빼다': 368,
#  '식': 369,
#  '따뜻하다': 370,
#  '위해': 371,
#  '력': 372,
#  '류': 373,
#  '세상': 374,
#  '찾다': 375,
#  '몇': 376,
#  '아직도': 377,
#  '훌륭하다': 378,
#  '년대': 379,
#  '이라고': 380,
#  '명': 381,
#  '공포영화': 382,
#  '미국': 383,
#  '웃음': 384,
#  '도대체': 385,
#  '걍': 386,
#  '생각나다': 387,
#  '아무': 388,
#  '앞': 389,
#  '설정': 390,
#  '오': 391,
#  '무엇': 392,
#  '마다': 393,
#  '그리다': 394,
#  '너': 395,
#  '써다': 396,
#  '죽이다': 397,
#  '어': 398,
#  '초반': 399,
#  '다르다': 400,
#  '물': 401,
#  '데': 402,
#  '뭘': 403,
#  '수작': 404,
#  '출연': 405,
#  '우리나라': 406,
#  '따다': 407,
#  '힘들다': 408,
#  '추억': 409,
#  '싫다': 410,
#  '엄청': 411,
#  '답답하다': 412,
#  '사실': 413,
#  '필요없다': 414,
#  '한국영': 415,
#  '가지': 416,
#  '남': 417,
#  '반': 418,
#  '지루함': 419,
#  '놓다': 420,
#  '멋있다': 421,
#  '시나리오': 422,
#  '신선하다': 423,
#  '관객': 424,
#  '이야': 425,
#  '아프다': 426,
#  '분위기': 427,
#  '대다': 428,
#  '장난': 429,
#  '팬': 430,
#  '기다': 431,
#  '시대': 432,
#  '어이없다': 433,
#  '해': 434,
#  '졸작': 435,
#  '세': 436,
#  '잊다': 437,
#  '나쁘다': 438,
#  '살': 439,
#  '이딴': 440,
#  '자신': 441,
#  '감정': 442,
#  '소리': 443,
#  '최고다': 444,
#  '더럽다': 445,
#  '이지만': 446,
#  '준': 447,
#  '엔딩': 448,
#  '접': 449,
#  '안타깝다': 450,
#  '영화관': 451,
#  '오늘': 452,
#  '엄마': 453,
#  '구': 454,
#  '멀다': 455,
#  '부족하다': 456,
#  '결국': 457,
#  '제발': 458,
#  '정신': 459,
#  '봄': 460,
#  '주': 461,
#  '인상': 462,
#  '스럽다': 463,
#  '라면': 464,
#  '배우다': 465,
#  '더빙': 466,
#  '원': 467,
#  '포스터': 468,
#  '캐스팅': 469,
#  '문제': 470,
#  '평가': 471,
#  '코믹': 472,
#  '니까': 473,
#  '얼마나': 474,
#  '아무리': 475,
#  '엉': 476,
#  '애니메이션': 477,
#  '그저': 478,
#  '함께': 479,
#  '어색하다': 480,
#  '서다': 481,
#  '음': 482,
#  '몰입도': 483,
#  '신': 484,
#  '비다': 485,
#  '낫다': 486,
#  '킬링타임': 487,
#  '티비': 488,
#  '기도': 489,
#  '망하다': 490,
#  '배경': 491,
#  '든': 492,
#  '유쾌하다': 493,
#  '첨': 494,
#  '살리다': 495,
#  '두다': 496,
#  '대해': 497,
#  '쓸다': 498,
#  '뒤': 499,
#  '맘': 500,
#  '나가다': 501,
#  '충격': 502,
#  '스릴': 503,
#  '적다': 504,
#  '진부하다': 505,
#  '완벽하다': 506,
#  '전쟁': 507,
#  '만화': 508,
#  '얘기': 509,
#  '존나': 510,
#  '책': 511,
#  '그렇게': 512,
#  '개연': 513,
#  '건가': 514,
#  '예술': 515,
#  '간': 516,
#  '머리': 517,
#  '매우': 518,
#  '머': 519,
#  '갈수록': 520,
#  '질': 521,
#  '즐겁다': 522,
#  '놀라다': 523,
#  '조': 524,
#  '얼굴': 525,
#  '보단': 526,
#  '웃기': 527,
#  '후회': 528,
#  '읽다': 529,
#  '이름': 530,
#  '옛날': 531,
#  '영화인': 532,
#  '너무나': 533,
#  '구성': 534,
#  '어디': 535,
#  '어울리다': 536,
#  '행복하다': 537,
#  '집중': 538,
#  '이후': 539,
#  '들이다': 540,
#  '울': 541,
#  '총': 542,
#  '꽤': 543,
#  '장르': 544,
#  '집': 545,
#  '새롭다': 546,
#  '주연': 547,
#  '날': 548,
#  '다큐': 549,
#  '시즌': 550,
#  '상황': 551,
#  '누구': 552,
#  '그래서': 553,
#  '상': 554,
#  '이리': 555,
#  '씬': 556,
#  '짜증': 557,
#  '억지': 558,
#  '언제': 559,
#  '생기다': 560,
#  '예전': 561,
#  '강추': 562,
#  '글': 563,
#  '충분하다': 564,
#  '아직': 565,
#  '비': 566,
#  '후반': 567,
#  '역사': 568,
#  '다운': 569,
#  '어느': 570,
#  '걸작': 571,
#  '궁금하다': 572,
#  '진': 573,
#  '불쌍하다': 574,
#  '밉다': 575,
#  '여기': 576,
#  '누가': 577,
#  '약간': 578,
#  '훨씬': 579,
#  '자기': 580,
#  '소름': 581,
#  '그것': 582,
#  '만점': 583,
#  '인물': 584,
#  '실화': 585,
#  '발연기': 586,
#  '그나마': 587,
#  '해도': 588,
#  '그대로': 589,
#  '방송': 590,
#  '심하다': 591,
#  '드리다': 592,
#  '분들': 593,
#  '시절': 594,
#  '잔인하다': 595,
#  '회': 596,
#  '비디오': 597,
#  '대체': 598,
#  '순수하다': 599,
#  '그런': 600,
#  '비슷하다': 601,
#  '한마디': 602,
#  '소설': 603,
#  '로맨스': 604,
#  '휴': 605,
#  '사회': 606,
#  '초딩': 607,
#  '아들': 608,
#  '어렵다': 609,
#  '부': 610,
#  '비교': 611,
#  '필요하다': 612,
#  '감성': 613,
#  '판': 614,
#  '네이버': 615,
#  '쉬다': 616,
#  '보': 617,
#  '따르다': 618,
#  '남기다': 619,
#  '다음': 620,
#  '만나다': 621,
#  '여주': 622,
#  '여배우': 623,
#  '전체': 624,
#  '간만': 625,
#  '떠나다': 626,
#  '타다': 627,
#  '죠': 628,
#  '꿈': 629,
#  '상당하다': 630,
#  '장': 631,
#  '라도': 632,
#  '편이': 633,
#  '사랑스럽다': 634,
#  '나이': 635,
#  '만큼': 636,
#  '이라도': 637,
#  '성룡': 638,
#  '당하다': 639,
#  '코': 640,
#  '나라': 641,
#  '재': 642,
#  '굉장하다': 643,
#  '재밋': 644,
#  '동안': 645,
#  '이르다': 646,
#  '혼자': 647,
#  '열': 648,
#  '삼류': 649,
#  '터지다': 650,
#  '순간': 651,
#  '굳다': 652,
#  '돌리다': 653,
#  '교훈': 654,
#  '쯤': 655,
#  '감사하다': 656,
#  '보다는': 657,
#  'ㅉㅉ': 658,
#  '빨리': 659,
#  '그만': 660,
#  '존재': 661,
#  '힘': 662,
#  '바로': 663,
#  '진정하다': 664,
#  '풀다': 665,
#  '주제': 666,
#  '바라다': 667,
#  '목소리': 668,
#  '낭비': 669,
#  '에요': 670,
#  '년도': 671,
#  '억': 672,
#  '잡다': 673,
#  '죽': 674,
#  '망치다': 675,
#  '돋다': 676,
#  '화려하다': 677,
#  '당신': 678,
#  '지나다': 679,
#  '거의': 680,
#  '안보': 681,
#  '몇번': 682,
#  '질질': 683,
#  '가볍다': 684,
#  '년전': 685,
#  '라니': 686,
#  '엄청나다': 687,
#  '맞추다': 688,
#  '독특하다': 689,
#  '말고': 690,
#  '줄거리': 691,
#  '성하다': 692,
#  '뜨다': 693,
#  '판타지': 694,
#  'ㅜ': 695,
#  '의도': 696,
#  '에선': 697,
#  '딸': 698,
#  '이번': 699,
#  '갑자기': 700,
#  '아버지': 701,
#  '좀비': 702,
#  '담다': 703,
#  '넣다': 704,
#  '그러나': 705,
#  '어른': 706,
#  '전부': 707,
#  '피': 708,
#  '점주': 709,
#  '당': 710,
#  '상영': 711,
#  '흥미롭다': 712,
#  '모': 713,
#  '시청률': 714,
#  'ㅎㅎㅎ': 715,
#  '실제': 716,
#  '소': 717,
#  '넘치다': 718,
#  '만하': 719,
#  'ㅡ': 720,
#  '으로도': 721,
#  '힘드다': 722,
#  '평론가': 723,
#  '곳': 724,
#  '맛': 725,
#  '점점': 726,
#  '필요': 727,
#  '땜': 728,
#  '기다리다': 729,
#  '단': 730,
#  '막': 731,
#  '한편': 732,
#  '그녀': 733,
#  '히': 734,
#  '제작': 735,
#  '화면': 736,
#  '사': 737,
#  '바': 738,
#  '대로': 739,
#  '극장판': 740,
#  '만들어지다': 741,
#  '초': 742,
#  '평': 743,
#  '이기다': 744,
#  '답': 745,
#  '중국': 746,
#  '형': 747,
#  '간다': 748,
#  '온': 749,
#  '각본': 750,
#  '억지스럽다': 751,
#  '에서도': 752,
#  '래': 753,
#  '밑': 754,
#  '볼때': 755,
#  '이하': 756,
#  '달다': 757,
#  '바꾸다': 758,
#  '관람': 759,
#  '란': 760,
#  '오글거리다': 761,
#  '저런': 762,
#  '선': 763,
#  '스타일': 764,
#  '일단': 765,
#  '세계': 766,
#  '가치': 767,
#  '선택': 768,
#  '성우': 769,
#  '똥': 770,
#  '요소': 771,
#  '항상': 772,
#  '터': 773,
#  '둘': 774,
#  '복수': 775,
#  '어디서': 776,
#  '햇': 777,
#  '에서는': 778,
#  '보내다': 779,
#  '뻔': 780,
#  '첫': 781,
#  '갖다': 782,
#  '올리다': 783,
#  '흥행': 784,
#  '부르다': 785,
#  '참고': 786,
#  '그때': 787,
#  '가보다': 788,
#  '드': 789,
#  '너무하다': 790,
#  '여러': 791,
#  '걸리다': 792,
#  '더욱': 793,
#  '치고': 794,
#  '진행': 795,
#  '확실하다': 796,
#  '라서': 797,
#  '들어가다': 798,
#  '또한': 799,
#  '거기': 800,
#  '아빠': 801,
#  '평범하다': 802,
#  '씩': 803,
#  '물론': 804,
#  '수가': 805,
#  '역대': 806,
#  '발': 807,
#  '잃다': 808,
#  '불편하다': 809,
#  'ㅋㅋㅋㅋㅋ': 810,
#  '인거': 811,
#  '완성': 812,
#  '전형': 813,
#  '편집': 814,
#  '멜로': 815,
#  '단순하다': 816,
#  '이냐': 817,
#  '상미': 818,
#  '듣다': 819,
#  '화이팅': 820,
#  '짧다': 821,
#  '끼다': 822,
#  '흐르다': 823,
#  '허무하다': 824,
#  '새끼': 825,
#  '짓': 826,
#  '이에요': 827,
#  '어이': 828,
#  'ㅠㅠㅠ': 829,
#  '때리다': 830,
#  '술': 831,
#  '역': 832,
#  '불륜': 833,
#  '걸다': 834,
#  '군': 835,
#  '귀': 836,
#  '탄탄하다': 837,
#  '가지다': 838,
#  '병맛': 839,
#  '돋보이다': 840,
#  '개그': 841,
#  '일이': 842,
#  '에겐': 843,
#  '엉망': 844,
#  '사건': 845,
#  '거지': 846,
#  '예상': 847,
#  '즐기다': 848,
#  '지겹다': 849,
#  '잠': 850,
#  '미화': 851,
#  '중반': 852,
#  '설명': 853,
#  '꿀잼': 854,
#  '소중하다': 855,
#  '그게': 856,
#  '똑같다': 857,
#  '어쩔': 858,
#  '과거': 859,
#  '메다': 860,
#  '불다': 861,
#  '찾아보다': 862,
#  '적당하다': 863,
#  '프랑스': 864,
#  '중요하다': 865,
#  '화보': 866,
#  '키': 867,
#  '훈훈하다': 868,
#  '흥미진진': 869,
#  '도저히': 870,
#  '손': 871,
#  '노력': 872,
#  '비추다': 873,
#  '댓글': 874,
#  '그래픽': 875,
#  '여서': 876,
#  '죽음': 877,
#  '흥미': 878,
#  '닿다': 879,
#  '갈다': 880,
#  '싸우다': 881,
#  '거리': 882,
#  '척': 883,
#  '무조건': 884,
#  '취향': 885,
#  '티': 886,
#  '원래': 887,
#  '몸': 888,
#  '식상하다': 889,
#  '리': 890,
#  '화가': 891,
#  '새': 892,
#  '마르다': 893,
#  '뛰어나다': 894,
#  '현': 895,
#  '자극': 896,
#  '배': 897,
#  '감상': 898,
#  '암': 899,
#  '며': 900,
#  '역겹다': 901,
#  '한심하다': 902,
#  '만으로도': 903,
#  '만이': 904,
#  '예': 905,
#  '학교': 906,
#  '길다': 907,
#  '괜히': 908,
#  '자꾸': 909,
#  '액션영화': 910,
#  '무': 911,
#  '관': 912,
#  '뭐라다': 913,
#  '예고편': 914,
#  '오히려': 915,
#  '바보': 916,
#  '결혼': 917,
#  '이라니': 918,
#  '헐다': 919,
#  '다가': 920,
#  '아저씨': 921,
#  '심리': 922,
#  '다루다': 923,
#  '게임': 924,
#  '속편': 925,
#  '용도': 926,
#  '흠': 927,
#  '연기자': 928,
#  '보이': 929,
#  '잘만': 930,
#  '마무리': 931,
#  '나서다': 932,
#  '올': 933,
#  '강하다': 934,
#  '관계': 935,
#  '맨': 936,
#  '양': 937,
#  '나르다': 938,
#  '왠만하다': 939,
#  '천재': 940,
#  '법': 941,
#  '미안하다': 942,
#  '땐': 943,
#  'ㄷㄷ': 944,
#  '억지로': 945,
#  '표정': 946,
#  '귀신': 947,
#  '한다는': 948,
#  '참신하다': 949,
#  '전설': 950,
#  '영환': 951,
#  '순': 952,
#  '최근': 953,
#  '유치': 954,
#  '기억나다': 955,
#  '현재': 956,
#  '상상': 957,
#  '동': 958,
#  '하하': 959,
#  '타임': 960,
#  '지루': 961,
#  '젠': 962,
#  '촬영': 963,
#  '아쉬움': 964,
#  '봣': 965,
#  '오빠': 966,
#  '드럽다': 967,
#  '대한민국': 968,
#  '오래': 969,
#  '다니다': 970,
#  '산': 971,
#  '대작': 972,
#  '조차': 973,
#  '빠져들다': 974,
#  '흘리다': 975,
#  '짐': 976,
#  '우연히': 977,
#  '엇': 978,
#  '길': 979,
#  '잊혀지다': 980,
#  '전편': 981,
#  '스타': 982,
#  '묘사': 983,
#  '메세지': 984,
#  '진지하다': 985,
#  '만의': 986,
#  '철학': 987,
#  '프로그램': 988,
#  '마': 989,
#  '동화': 990,
#  '겁나다': 991,
#  '타': 992,
#  '프로': 993,
#  '돌아가다': 994,
#  '그림': 995,
#  '작다': 996,
#  '만에': 997,
#  '여전하다': 998,
#  '사라지다': 999,
#  '예요': 1000,
#  ...}

# %%
# 패딩처리
train_padded = pad_sequences(train_sequences, maxlen=10, padding='post')
test_padded = pad_sequences(test_sequences, maxlen=10, padding='post')

train_label = np.array(train_data['label'])
test_label = np.array(test_data['label'])

train_padded[0]
# Out:
# array([ 56, 466,  20, 267, 668,   0,   0,   0,   0,   0], dtype=int32)

# %%
# 모델생성
model = Sequential()
model.add(Embedding(30000, 10))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 10)          300000
#
#  lstm (LSTM)                 (None, 128)               71168
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 371,297
# Trainable params: 371,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델설정
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# %%
# 모델학습
model.fit(train_padded, train_label, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 20s 12ms/step - loss: 0.4365 - acc: 0.7904 - val_loss: 0.3904 - val_acc: 0.8247
# Epoch 2/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3510 - acc: 0.8459 - val_loss: 0.3911 - val_acc: 0.8232
# Epoch 3/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3235 - acc: 0.8602 - val_loss: 0.3979 - val_acc: 0.8225
# Epoch 4/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3019 - acc: 0.8704 - val_loss: 0.3989 - val_acc: 0.8261
# Epoch 5/10
# 938/938 [==============================] - 10s 10ms/step - loss: 0.2777 - acc: 0.8820 - val_loss: 0.4117 - val_acc: 0.8241
# Epoch 6/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2559 - acc: 0.8925 - val_loss: 0.4284 - val_acc: 0.8226
# Epoch 7/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2347 - acc: 0.9023 - val_loss: 0.4697 - val_acc: 0.8190
# Epoch 8/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2145 - acc: 0.9106 - val_loss: 0.5383 - val_acc: 0.8144
# Epoch 9/10
# 938/938 [==============================] - 10s 10ms/step - loss: 0.1971 - acc: 0.9176 - val_loss: 0.5627 - val_acc: 0.8141
# Epoch 10/10
# 938/938 [==============================] - 10s 10ms/step - loss: 0.1805 - acc: 0.9247 - val_loss: 0.6038 - val_acc: 0.8120

# %%
# 모델평가
result = model.evaluate(test_padded, test_label)
result
# Out:
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6016 - acc: 0.8110
# [0.6016420125961304, 0.8110399842262268]

# %%
# 모델저장
model.save('/content/drive/MyDrive/파이썬 데이터 과학 실습/file/movie_model.h5')

# %%
# 모델 테스트 함수
def sentiment_predict(s):
  s = re.sub("[^가-힣ㅏ-ㅣㄱ-ㅎ]", "", s)

  s = okt.morphs(s, stem=True)
  s = [word for word in s if not word in stop_words]

  sequences = tokenizer.texts_to_sequences([s])
  padded = pad_sequences(sequences, maxlen=10, padding='post')

  score = float(model.predict(padded))
  return score

# %%
while True:
  txt = input('입력 :')
  score = sentiment_predict(txt)

  if score > 0.5:
    print("{:.2f} 확률로 긍정입니다.\n".format(score * 100))
  else:
    print("{:.2f} 확률로 부정입니다.\n".format((1 - score) * 100))
# Out:
# 입력 :별로였어요
# 97.12 확률로 부정입니다.
#
# 입력 :안녕하세요
# 98.46 확률로 부정입니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-733e7c0f76e3> in <module>()
#       1 while True:
# ----> 2   txt = input('입력 :')
#       3   score = sentiment_predict(txt)
#       4
#       5   if score > 0.5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
